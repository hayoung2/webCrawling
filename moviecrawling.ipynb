# %%
# !pip install bs4

# %%
# !pip install bs4 requests

# %%
#iframe 은 페이지를 더 넣은 것
import requests

# %%
from bs4 import BeautifulSoup

url='http://www.cgv.co.kr/common/showtimes/iframeTheater.aspx?areacode=01&theatercode=0011&date=20200302'

# %%
for i in title_list:
    print(i.select_one('a > strong').text.strip())
# Out:
# 인비저블맨
# 작은 아씨들
# 젠틀맨
# 기생충
# 정직한 후보
# 지푸라기라도 잡고 싶은 짐승들
# 1917
# 조조 래빗
# 하이, 젝시
# 클로젯

# %%
# Out:
# IMAX 없음

# %%
# !pip install python-telegram-bot
import telegram

# %%
bot=telegram.Bot(token='1098070850:AAHAfqR8v1Q9AXgsnokgvWCeiIoD7ktEHI0')
new =telegram.Bot(token='1117126482:AAEEWAJ7EkcRwEWhC9O7CAG_q3mdZbxMtlQ')

# %%
for i in new.getUpdates():
    print(i.message)
# 위에껄로 id 알아내야하는데 jupyter 좆만해서 안받아줌 ㅋ

# %%
# !pip install apscheduler

# %%
def job_function():
    html=requests.get(url)
    soup =BeautifulSoup(html.text,'html.parser')
    title_list=soup.select('div.info-movie')
    imax=soup.select_one('span.imax')
    if(imax):
        imax=imax.find_parent('div',class_='col-times')
        title=imax.select_one('div.info-movie > a > strong').text.strip()
        bot.sendMessage(chat_id=1149919304,text=title+' IMAX 예매가 열렸습니다.')
        sched.pause();

# %%
from apscheduler.schedulers.blocking import BlockingScheduler

# %%
sched =BlockingScheduler()
sched.add_job(job_function,'interval',seconds=30)
sched.start()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-b87b484cfa60> in <module>
#       1 sched =BlockingScheduler()
#       2 sched.add_job(job_function,'interval',seconds=30)
# ----> 3 sched.start()
#
# ~\Anaconda3\lib\site-packages\apscheduler\schedulers\blocking.py in start(self, *args, **kwargs)
#      17         self._event = Event()
#      18         super(BlockingScheduler, self).start(*args, **kwargs)
# ---> 19         self._main_loop()
#      20
#      21     def shutdown(self, wait=True):
#
# ~\Anaconda3\lib\site-packages\apscheduler\schedulers\blocking.py in _main_loop(self)
#      26         wait_seconds = TIMEOUT_MAX
#      27         while self.state != STATE_STOPPED:
# ---> 28             self._event.wait(wait_seconds)
#      29             self._event.clear()
#      30             wait_seconds = self._process_jobs()
#
# ...
